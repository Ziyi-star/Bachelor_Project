# %% [markdown]
# # Autoencoder Training using best parameters

# %%
import pandas as pd #reading dataset
import matplotlib as mpl    #plotting, visualization
import matplotlib.pyplot as plt
import tensorflow as tf #building model
from tensorflow.keras.models import Model
import numpy as np  #playing output with model
from sklearn.preprocessing import StandardScaler
import json

import sys
sys.path.append('../../../')   # Add parent directory to Python path
from utils.plots import *

# %%
df = pd.read_csv('../../../data/handlebar/train_data.csv') 
df
# Out:
#       curb_scene    Acc-Z_1    Acc-Z_2    Acc-Z_3    Acc-Z_4    Acc-Z_5  \
# 0            0.0   9.595963  11.133041   4.472366   4.592072   5.310333
# 1            0.0  10.783478   6.344635   7.445969   5.238510  13.091492
# 2            0.0   3.337524   7.517792   9.902420  10.031708   8.283936
# 3            0.0  18.243820  16.591812   5.564117   0.545883   5.013458
# 4            0.0   4.596863   6.186615  15.246277  13.919891   8.963898
# ...          ...        ...        ...        ...        ...        ...
# 7448         0.0  11.846512  12.756302  10.113113   3.821152   2.154785
# 7449         0.0   8.657440   8.633499   8.652649   8.609543   8.633499
# 7450         0.0   8.643066   8.647858   8.633499   8.638275   8.643066
# 7451         0.0   8.015793   7.814682   4.362228   8.906433  12.660538
# 7452         0.0   8.604767   8.604767   8.628708   8.609543   8.619125
#
#         Acc-Z_6    Acc-Z_7    Acc-Z_8    Acc-Z_9  ...   Acc-Z_91   Acc-Z_92  \
# 0     17.501617  17.319656  11.291061   1.508347  ...  12.737152   5.166687
# 1     11.386826  10.783478  11.496963   6.526596  ...   1.403000   5.516235
# 2      4.472366   3.035843   3.643982   7.814682  ...  14.216766   7.493851
# 3     14.211975  14.006073   8.705322   2.978394  ...  11.310211 -10.534485
# 4      2.796432   6.962341  13.867218  13.541611  ...  14.494492   3.821152
# ...         ...        ...        ...        ...  ...        ...        ...
# 7448   4.836289  -0.900223   8.734055   6.368576  ...   7.220917   8.556885
# 7449   8.638275   8.647858   8.623917   8.619125  ...   8.643066   8.647858
# 7450   8.638275   8.633499   8.638275   8.643066  ...   8.643066   8.623917
# 7451  13.761871  10.079590   8.599976   5.415680  ...  11.520905  22.045807
# 7452   8.628708   8.623917   8.633499   8.628708  ...   8.609543   8.609543
#
#        Acc-Z_93   Acc-Z_94   Acc-Z_95   Acc-Z_96   Acc-Z_97   Acc-Z_98  \
# 0      1.039078   4.481949  12.052414  14.475342  10.692505   5.358231
# 1     14.652512  20.005950  19.383453   8.058884  -1.537079   1.977615
# 2      5.602432   4.893753   6.569687   9.054871  15.021225  13.584702
# 3     16.476898  21.538239  -7.268799 -34.404680 -28.218063   5.147537
# 4     -0.531509   0.780502  14.202408  24.056946  18.804062   7.503433
# ...         ...        ...        ...        ...        ...        ...
# 7448   5.674255  13.450623  12.866440  11.535263   9.323029   9.375702
# 7449   8.643066   8.633499   8.647858   8.643066   8.633499   8.619125
# 7450   8.652649   8.633499   8.633499   8.652649   8.647858   8.652649
# 7451  16.041153   6.971909  -0.167587   5.171478  11.343735  21.327545
# 7452   8.599976   8.609543   8.614334   8.628708   8.633499   8.638275
#
#        Acc-Z_99  Acc-Z_100
# 0      9.576813  11.377243
# 1      7.565674  12.028473
# 2      7.206543   3.801987
# 3     11.401184 -16.716324
# 4      4.218582   7.766785
# ...         ...        ...
# 7448  12.971787  10.429138
# 7449   8.647858   8.633499
# 7450   8.633499   8.647858
# 7451   9.629486  -5.104431
# 7452   8.633499   8.643066
#
# [7453 rows x 101 columns]

# %%
#scaling data, because neural network works better with scaled data
scaler = StandardScaler()
data_scaled = scaler.fit(df.iloc[:, 1:])
#transform data
train_data_scaled = scaler.transform(df.iloc[:, 1:])

# %%
# Convert the scaled data back to DataFrames for further processing
train_data_scaled_df = pd.DataFrame(train_data_scaled, columns=df.columns[1:])
train_data_scaled_df['curb_scene'] = df['curb_scene'].values
train_data_scaled_df.shape
# Out:
# (7453, 101)

# %%
# Filter and slice the data
normal_train_data_scaled = train_data_scaled_df[train_data_scaled_df['curb_scene'] == 0.0].iloc[:, :-1]
abnormal_train_data_scaled = train_data_scaled_df[train_data_scaled_df['curb_scene'] == 1.0].iloc[:, :-1]
normal_train_data_scaled.shape,abnormal_train_data_scaled.shape
# Out:
# ((7178, 100), (275, 100))

# %%
# Cast to float32
normal_train_data_scaled = normal_train_data_scaled.astype("float32")
abnormal_train_data_scaled = abnormal_train_data_scaled.astype("float32")

# %%
from keras.models import Sequential
from keras.layers import Input, Dropout
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.models import Model

# Define the autoencoder model using Sequential API
model = Sequential([
    # Encoder layers
    Input(shape=(100,)),  # Input shape based on your data
    Dense(256, activation='tanh'),
    Dense(224, activation='tanh'),
    Dense(160, activation='tanh'),
    
    # Decoder layers
    Dense(160, activation='tanh'),
    Dense(224, activation='tanh'),
    Dense(256, activation='tanh'),
    Dense(100, activation='tanh')  # Output shape matches input shape
])

optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='mae')

# Display model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │        25,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 224)            │        57,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 160)            │        36,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 160)            │        25,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 224)            │        36,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │        57,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 100)            │        25,700 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 264,548 (1.01 MB)
#  Trainable params: 264,548 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
## Compile the model
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, mode='min')
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='mae')

# Display model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │        25,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 224)            │        57,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 160)            │        36,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 160)            │        25,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 224)            │        36,064 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │        57,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 100)            │        25,700 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 264,548 (1.01 MB)
#  Trainable params: 264,548 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# seprate class as well for normal and abnormal data invalidation data
history = model.fit(normal_train_data_scaled, 
                    normal_train_data_scaled,
                    epochs=200, 
                    batch_size=512,
                    validation_split=0.3, 
                    shuffle=True, 
                    callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - loss: 0.4878 - val_loss: 0.4505
# Epoch 2/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4558 - val_loss: 0.4212
# Epoch 3/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4204 - val_loss: 0.3978
# Epoch 4/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3967 - val_loss: 0.3789
# Epoch 5/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3832 - val_loss: 0.3636
# Epoch 6/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3675 - val_loss: 0.3511
# Epoch 7/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3574 - val_loss: 0.3407
# Epoch 8/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3440 - val_loss: 0.3318
# Epoch 9/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3379 - val_loss: 0.3240
# Epoch 10/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3293 - val_loss: 0.3171
# Epoch 11/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3170 - val_loss: 0.3108
# Epoch 12/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3126 - val_loss: 0.3050
# Epoch 13/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.3114 - val_loss: 0.2996
# Epoch 14/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3064 - val_loss: 0.2946
# Epoch 15/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2922 - val_loss: 0.2899
# Epoch 16/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2899 - val_loss: 0.2855
# Epoch 17/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.2915 - val_loss: 0.2813
# Epoch 18/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2871 - val_loss: 0.2774
# Epoch 19/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2747 - val_loss: 0.2736
# Epoch 20/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2750 - val_loss: 0.2701
# Epoch 21/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.2711 - val_loss: 0.2667
# Epoch 22/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2695 - val_loss: 0.2635
# Epoch 23/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2658 - val_loss: 0.2604
# Epoch 24/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2629 - val_loss: 0.2575
# Epoch 25/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2597 - val_loss: 0.2547
# Epoch 26/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2572 - val_loss: 0.2521
# Epoch 27/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2568 - val_loss: 0.2495
# Epoch 28/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2516 - val_loss: 0.2470
# Epoch 29/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2505 - val_loss: 0.2447
# Epoch 30/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2480 - val_loss: 0.2425
# Epoch 31/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2444 - val_loss: 0.2403
# Epoch 32/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2388 - val_loss: 0.2383
# Epoch 33/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2362 - val_loss: 0.2363
# Epoch 34/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2332 - val_loss: 0.2344
# Epoch 35/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2341 - val_loss: 0.2326
# Epoch 36/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2323 - val_loss: 0.2308
# Epoch 37/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2296 - val_loss: 0.2291
# Epoch 38/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2271 - val_loss: 0.2274
# Epoch 39/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.2255 - val_loss: 0.2258
# Epoch 40/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2244 - val_loss: 0.2243
# Epoch 41/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2249 - val_loss: 0.2228
# Epoch 42/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2243 - val_loss: 0.2214
# Epoch 43/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2203 - val_loss: 0.2201
# Epoch 44/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2202 - val_loss: 0.2188
# Epoch 45/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2162 - val_loss: 0.2175
# Epoch 46/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2164 - val_loss: 0.2163
# Epoch 47/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2133 - val_loss: 0.2151
# Epoch 48/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2151 - val_loss: 0.2139
# Epoch 49/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2107 - val_loss: 0.2128
# Epoch 50/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2107 - val_loss: 0.2117
# Epoch 51/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2118 - val_loss: 0.2106
# Epoch 52/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2078 - val_loss: 0.2095
# Epoch 53/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2069 - val_loss: 0.2085
# Epoch 54/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2114 - val_loss: 0.2075
# Epoch 55/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2088 - val_loss: 0.2065
# Epoch 56/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2036 - val_loss: 0.2055
# Epoch 57/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.2049 - val_loss: 0.2045
# Epoch 58/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.2040 - val_loss: 0.2036
# Epoch 59/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2010 - val_loss: 0.2026
# Epoch 60/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.2007 - val_loss: 0.2017
# Epoch 61/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2005 - val_loss: 0.2008
# Epoch 62/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1990 - val_loss: 0.1999
# Epoch 63/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1964 - val_loss: 0.1990
# Epoch 64/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1943 - val_loss: 0.1982
# Epoch 65/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1928 - val_loss: 0.1973
# Epoch 66/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1952 - val_loss: 0.1965
# Epoch 67/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1961 - val_loss: 0.1957
# Epoch 68/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1939 - val_loss: 0.1949
# Epoch 69/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1896 - val_loss: 0.1941
# Epoch 70/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1886 - val_loss: 0.1934
# Epoch 71/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1919 - val_loss: 0.1926
# Epoch 72/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1890 - val_loss: 0.1919
# Epoch 73/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1879 - val_loss: 0.1911
# Epoch 74/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1864 - val_loss: 0.1905
# Epoch 75/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1889 - val_loss: 0.1897
# Epoch 76/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1868 - val_loss: 0.1890
# Epoch 77/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1863 - val_loss: 0.1884
# Epoch 78/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1851 - val_loss: 0.1877
# Epoch 79/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1826 - val_loss: 0.1870
# Epoch 80/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1833 - val_loss: 0.1864
# Epoch 81/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1842 - val_loss: 0.1857
# Epoch 82/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1823 - val_loss: 0.1851
# Epoch 83/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1818 - val_loss: 0.1845
# Epoch 84/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1797 - val_loss: 0.1839
# Epoch 85/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1828 - val_loss: 0.1833
# Epoch 86/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1802 - val_loss: 0.1827
# Epoch 87/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1779 - val_loss: 0.1821
# Epoch 88/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1785 - val_loss: 0.1815
# Epoch 89/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1775 - val_loss: 0.1810
# Epoch 90/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1811 - val_loss: 0.1804
# Epoch 91/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1782 - val_loss: 0.1798
# Epoch 92/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1750 - val_loss: 0.1793
# Epoch 93/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1745 - val_loss: 0.1787
# Epoch 94/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1737 - val_loss: 0.1782
# Epoch 95/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1754 - val_loss: 0.1777
# Epoch 96/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1726 - val_loss: 0.1771
# Epoch 97/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1698 - val_loss: 0.1766
# Epoch 98/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1736 - val_loss: 0.1761
# Epoch 99/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1691 - val_loss: 0.1756
# Epoch 100/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1713 - val_loss: 0.1751
# Epoch 101/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1734 - val_loss: 0.1746
# Epoch 102/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1692 - val_loss: 0.1741
# Epoch 103/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1695 - val_loss: 0.1737
# Epoch 104/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1688 - val_loss: 0.1732
# Epoch 105/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1703 - val_loss: 0.1727
# Epoch 106/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1656 - val_loss: 0.1722
# Epoch 107/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1681 - val_loss: 0.1718
# Epoch 108/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1678 - val_loss: 0.1713
# Epoch 109/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1680 - val_loss: 0.1709
# Epoch 110/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1687 - val_loss: 0.1705
# Epoch 111/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1657 - val_loss: 0.1700
# Epoch 112/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1658 - val_loss: 0.1696
# Epoch 113/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1649 - val_loss: 0.1691
# Epoch 114/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1639 - val_loss: 0.1687
# Epoch 115/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1649 - val_loss: 0.1683
# Epoch 116/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1648 - val_loss: 0.1678
# Epoch 117/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1632 - val_loss: 0.1674
# Epoch 118/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1672 - val_loss: 0.1670
# Epoch 119/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1629 - val_loss: 0.1666
# Epoch 120/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1651 - val_loss: 0.1661
# Epoch 121/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1590 - val_loss: 0.1658
# Epoch 122/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1611 - val_loss: 0.1653
# Epoch 123/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1623 - val_loss: 0.1649
# Epoch 124/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1597 - val_loss: 0.1646
# Epoch 125/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1581 - val_loss: 0.1641
# Epoch 126/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1608 - val_loss: 0.1638
# Epoch 127/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1590 - val_loss: 0.1634
# Epoch 128/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1607 - val_loss: 0.1630
# Epoch 129/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1584 - val_loss: 0.1626
# Epoch 130/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1590 - val_loss: 0.1622
# Epoch 131/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1550 - val_loss: 0.1619
# Epoch 132/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1595 - val_loss: 0.1614
# Epoch 133/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1578 - val_loss: 0.1611
# Epoch 134/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1567 - val_loss: 0.1607
# Epoch 135/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1557 - val_loss: 0.1603
# Epoch 136/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1555 - val_loss: 0.1600
# Epoch 137/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1556 - val_loss: 0.1597
# Epoch 138/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1541 - val_loss: 0.1592
# Epoch 139/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1550 - val_loss: 0.1589
# Epoch 140/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1558 - val_loss: 0.1585
# Epoch 141/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1555 - val_loss: 0.1582
# Epoch 142/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1538 - val_loss: 0.1579
# Epoch 143/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1523 - val_loss: 0.1575
# Epoch 144/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1549 - val_loss: 0.1572
# Epoch 145/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1515 - val_loss: 0.1569
# Epoch 146/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1511 - val_loss: 0.1566
# Epoch 147/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1513 - val_loss: 0.1563
# Epoch 148/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1496 - val_loss: 0.1559
# Epoch 149/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1485 - val_loss: 0.1556
# Epoch 150/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1527 - val_loss: 0.1553
# Epoch 151/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1511 - val_loss: 0.1550
# Epoch 152/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1505 - val_loss: 0.1547
# Epoch 153/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1508 - val_loss: 0.1544
# Epoch 154/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1509 - val_loss: 0.1540
# Epoch 155/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1485 - val_loss: 0.1538
# Epoch 156/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1492 - val_loss: 0.1535
# Epoch 157/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1498 - val_loss: 0.1532
# Epoch 158/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1479 - val_loss: 0.1529
# Epoch 159/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1485 - val_loss: 0.1526
# Epoch 160/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1485 - val_loss: 0.1523
# Epoch 161/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1501 - val_loss: 0.1521
# Epoch 162/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1470 - val_loss: 0.1518
# Epoch 163/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1465 - val_loss: 0.1515
# Epoch 164/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1490 - val_loss: 0.1512
# Epoch 165/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1482 - val_loss: 0.1510
# Epoch 166/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1467 - val_loss: 0.1506
# Epoch 167/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1438 - val_loss: 0.1504
# Epoch 168/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1449 - val_loss: 0.1502
# Epoch 169/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1455 - val_loss: 0.1499
# Epoch 170/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1437 - val_loss: 0.1497
# Epoch 171/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1452 - val_loss: 0.1494
# Epoch 172/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1411 - val_loss: 0.1492
# Epoch 173/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1460 - val_loss: 0.1489
# Epoch 174/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1452 - val_loss: 0.1487
# Epoch 175/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1427 - val_loss: 0.1484
# Epoch 176/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1437 - val_loss: 0.1482
# Epoch 177/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.1433 - val_loss: 0.1480
# Epoch 178/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.1394 - val_loss: 0.1477
# Epoch 179/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.1417 - val_loss: 0.1475
# Epoch 180/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1442 - val_loss: 0.1472
# Epoch 181/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.1433 - val_loss: 0.1470
# Epoch 182/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.1421 - val_loss: 0.1468
# Epoch 183/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1422 - val_loss: 0.1465
# Epoch 184/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.1396 - val_loss: 0.1464
# Epoch 185/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 0.1384 - val_loss: 0.1462
# Epoch 186/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1408 - val_loss: 0.1460
# Epoch 187/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.1385 - val_loss: 0.1457
# Epoch 188/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.1406 - val_loss: 0.1455
# Epoch 189/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.1415 - val_loss: 0.1453
# Epoch 190/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1418 - val_loss: 0.1451
# Epoch 191/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.1428 - val_loss: 0.1450
# Epoch 192/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1381 - val_loss: 0.1447
# Epoch 193/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1415 - val_loss: 0.1445
# Epoch 194/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1369 - val_loss: 0.1443
# Epoch 195/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1375 - val_loss: 0.1441
# Epoch 196/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1379 - val_loss: 0.1439
# Epoch 197/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1390 - val_loss: 0.1437
# Epoch 198/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1371 - val_loss: 0.1435
# Epoch 199/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1386 - val_loss: 0.1433
# Epoch 200/200
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1408 - val_loss: 0.1431

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], 'b-', label='Training loss', linewidth=2)
plt.plot(history.history['val_loss'], 'r--', label='Validation loss', linewidth=2)

# Customize the plot
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MAE)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend with larger font
plt.legend(fontsize=12)

# Adjust y-axis to start from 0
plt.ylim(bottom=0)

# Add minor grid lines for finer scale
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', alpha=0.4)

# Make axis labels more readable
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Adjust layout to prevent label cutoff
plt.tight_layout()

plt.show()

# %%
from keras import ops
model.save('../../../models/autoencoder_best.keras')

# %%
load_model = tf.keras.models.load_model('../../../models/autoencoder_best.keras')

# %%
#Plot the reconstruction error on normal data from the training set
reconstructions_normal = load_model.predict(normal_train_data_scaled)
train_loss_normal = tf.keras.losses.mae(reconstructions_normal, normal_train_data_scaled)

plt.hist(train_loss_normal[None,:], bins=50)
plt.xlabel("Train loss of normal data")
plt.ylabel("No of examples")
plt.show()
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
#Plot the reconstruction error on abnormal data from the training set
reconstructions_abnormal = load_model.predict(abnormal_train_data_scaled)
train_loss_abnormal = tf.keras.losses.mae(reconstructions_abnormal, abnormal_train_data_scaled)

plt.hist(train_loss_abnormal[None,:], bins=50)
plt.xlabel("Train loss of abnormal data")
plt.ylabel("No of examples")
plt.show()

print("Min value:", tf.reduce_min(train_loss_abnormal).numpy())
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Min value: 0.42725292

# %%
# Visualize threshold with histogram
plt.figure(figsize=(10, 6))
plt.hist(train_loss_normal, bins=50, alpha=0.7, label='Normal')
plt.hist(train_loss_abnormal, bins=50, alpha=0.7, label='Abnormal')
plt.ylim(0, 60)
#plt.axvline(threshold, color='r', linestyle='dashed', linewidth=2, label=f'Threshold: {threshold:.4f}')
plt.xlabel('Reconstruction Error (MAE)')
plt.ylabel('Number of Examples')
plt.title('Distribution of Reconstruction Errors')
plt.legend()
plt.show()

# %%
best_threshold, best_f1 = plt_optimal_threshold(train_loss_normal, train_loss_abnormal)
# Out:
# Optimal threshold (best F1 score): 0.8046
# Best F1 score: 0.9493

# %%
# Calculate thresholds
high_threshold = np.percentile(train_loss_normal, 99.99)  # Loose threshold (99th percentile)
print("High threshold: ", high_threshold)
# Out:
# High threshold:  1.275661

# %%
best_threshold = 0.81
high_threshold = 1.27
low_threshold = 0.39

# %%
# Save threshold to a JSON file
threshold_data = {
    'low_threshold': float(low_threshold),  # Convert to native Python float
    'middle_threshold': float(best_threshold),  # Convert numpy.float32 to native Python float
    'high_threshold': float(high_threshold),  # Convert numpy.float32 to native Python float
}
# Save in the same directory as the model
with open('../../../models/autoencoder_thresholds.json', 'w') as f:
    json.dump(threshold_data, f)

# %%
# Verify the saved data
with open('../../../models/autoencoder_thresholds.json', 'r') as f:
    loaded_thresholds = json.load(f)
print("Saved thresholds:", loaded_thresholds)
# Out:
# Saved thresholds: {'low_threshold': 0.39, 'middle_threshold': 0.81, 'high_threshold': 1.27}
