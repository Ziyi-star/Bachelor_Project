# %% [markdown]
# <a href="https://colab.research.google.com/github/Ziyi-star/Bachelor-Project/blob/main/notebooks/handlebar/LSTM/Lstm__Handlebar_best.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For Vscode
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib import dates as md
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
import tensorflow as tf #building model

import sys
sys.path.append('../../../')   # Add parent directory to Python path
from utils.plots import *

df = pd.read_csv('../../../data/handlebar/train_data.csv')
# 0 for normal, 1 for abnormal
df['curb_scene'].value_counts()
#df.drop('Unnamed: 0', axis=1, inplace=True)
print(df.shape)
df.head()
# Out:
# (7453, 101)
#    curb_scene    Acc-Z_1    Acc-Z_2    Acc-Z_3    Acc-Z_4    Acc-Z_5  \
# 0         0.0   9.595963  11.133041   4.472366   4.592072   5.310333
# 1         0.0  10.783478   6.344635   7.445969   5.238510  13.091492
# 2         0.0   3.337524   7.517792   9.902420  10.031708   8.283936
# 3         0.0  18.243820  16.591812   5.564117   0.545883   5.013458
# 4         0.0   4.596863   6.186615  15.246277  13.919891   8.963898
#
#      Acc-Z_6    Acc-Z_7    Acc-Z_8    Acc-Z_9  ...   Acc-Z_91   Acc-Z_92  \
# 0  17.501617  17.319656  11.291061   1.508347  ...  12.737152   5.166687
# 1  11.386826  10.783478  11.496963   6.526596  ...   1.403000   5.516235
# 2   4.472366   3.035843   3.643982   7.814682  ...  14.216766   7.493851
# 3  14.211975  14.006073   8.705322   2.978394  ...  11.310211 -10.534485
# 4   2.796432   6.962341  13.867218  13.541611  ...  14.494492   3.821152
#
#     Acc-Z_93   Acc-Z_94   Acc-Z_95   Acc-Z_96   Acc-Z_97   Acc-Z_98  \
# 0   1.039078   4.481949  12.052414  14.475342  10.692505   5.358231
# 1  14.652512  20.005950  19.383453   8.058884  -1.537079   1.977615
# 2   5.602432   4.893753   6.569687   9.054871  15.021225  13.584702
# 3  16.476898  21.538239  -7.268799 -34.404680 -28.218063   5.147537
# 4  -0.531509   0.780502  14.202408  24.056946  18.804062   7.503433
#
#     Acc-Z_99  Acc-Z_100
# 0   9.576813  11.377243
# 1   7.565674  12.028473
# 2   7.206543   3.801987
# 3  11.401184 -16.716324
# 4   4.218582   7.766785
#
# [5 rows x 101 columns]

# %%
# For Colab
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from datetime import datetime
from matplotlib import pyplot as plt
from matplotlib import dates as md
from sklearn.preprocessing import StandardScaler
import tensorflow as tf #building model


import os
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/Project/data/processed_segments_overlap_50_more.csv')
# # 0 for normal, 1 for abnormal
df['curb_scene'].value_counts()
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Unnamed: 0  curb_scene   Acc-Z_1   Acc-Z_2   Acc-Z_3   Acc-Z_4   Acc-Z_5  \
# 0           0         0.0  8.762772  8.753204  8.762772  8.781937  8.753204
# 1           0         0.0  8.762772  8.762772  8.748413  8.767563  8.729263
# 2           0         0.0  8.781937  8.796295  8.772354  8.772354  8.772354
# 3           0         0.0  8.781937  8.753204  8.801086  8.753204  8.829819
# 4           0         0.0  8.757996  8.762772  8.777145  8.767563  8.786728
#
#     Acc-Z_6   Acc-Z_7   Acc-Z_8  ...  Acc-Z_91  Acc-Z_92  Acc-Z_93  Acc-Z_94  \
# 0  8.748413  8.738831  8.748413  ...  8.786728  8.801086  8.820236  8.786728
# 1  8.695740  8.724472  8.767563  ...  8.753204  8.772354  8.786728  8.781937
# 2  8.786728  8.781937  8.801086  ...  8.777145  8.753204  8.767563  8.762772
# 3  8.753204  8.786728  8.815445  ...  8.805878  8.796295  8.781937  8.801086
# 4  8.777145  8.753204  8.757996  ...  8.757996  8.757996  8.772354  8.767563
#
#    Acc-Z_95  Acc-Z_96  Acc-Z_97  Acc-Z_98  Acc-Z_99  Acc-Z_100
# 0  8.777145  8.772354  8.781937  8.801086  8.781937   8.753204
# 1  8.786728  8.777145  8.738831  8.820236  8.738831   8.757996
# 2  8.762772  8.753204  8.748413  8.762772  8.772354   8.767563
# 3  8.810669  8.796295  8.805878  8.791504  8.791504   8.772354
# 4  8.757996  8.743622  8.777145  8.743622  8.786728   8.796295
#
# [5 rows x 102 columns]

# %%
#scaling data, because neural network works better with scaled data
scaler = StandardScaler()
train_data_scaled = scaler.fit_transform(df.iloc[:, 1:])
train_data_scaled.shape
# Out:
# (7453, 100)

# %%
# Convert the scaled data back to DataFrames for further processing
# takes all column names from the original DataFrame starting from index 1
train_data_scaled_df = pd.DataFrame(train_data_scaled, columns=df.columns[1:])
# Add the 'curb_scene', 'start_time', and 'end_time' columns back to the scaled DataFrames
train_data_scaled_df['curb_scene'] = df['curb_scene'].values
train_data_scaled_df.shape
# Out:
# (7453, 101)

# %%
# Filter and slice the data
normal_train_data_scaled = train_data_scaled_df[train_data_scaled_df['curb_scene'] == 0.0].iloc[:, :-1]
abnormal_train_data_scaled = train_data_scaled_df[train_data_scaled_df['curb_scene'] == 1.0].iloc[:, :-1]
normal_train_data_scaled.shape, abnormal_train_data_scaled.shape
# Out:
# ((7178, 100), (275, 100))

# %%
# Cast to float32
normal_train_data_scaled = normal_train_data_scaled.astype("float32")
abnormal_train_data_scaled = abnormal_train_data_scaled.astype("float32")
normal_train_data_scaled.shape, abnormal_train_data_scaled.shape
# Out:
# ((7178, 100), (275, 100))

# %%
# Reshape the data for LSTM input((samples, timesteps, features))
normal_train_data_scaled_lstm = np.expand_dims(normal_train_data_scaled, axis=1)
abnormal_train_data_scaled_lstm = np.expand_dims(abnormal_train_data_scaled, axis=1)
normal_train_data_scaled_lstm.shape, abnormal_train_data_scaled_lstm.shape
# Out:
# ((7178, 1, 100), (275, 1, 100))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Input, Dropout
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.models import Model

model = Sequential()
# Encoder
model.add(Input(shape=(normal_train_data_scaled_lstm.shape[1], normal_train_data_scaled_lstm.shape[2])))
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(LSTM(224, activation='tanh', return_sequences=True))

#decoder
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(LSTM(224, activation='tanh', return_sequences=True))
model.add(TimeDistributed(Dense(normal_train_data_scaled_lstm.shape[2])))
model.compile(optimizer='adam', loss='mae')
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1, 224)         │       291,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 1, 224)         │       402,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 1, 224)         │       402,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 1, 224)         │       402,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 1, 100)         │        22,500 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,520,612 (5.80 MB)
#  Trainable params: 1,520,612 (5.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# define early stopping to prevent overfit
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss",
                                               patience=10,
                                               mode="min",
                                               verbose=1,
                                               restore_best_weights=True)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.00044)
model.compile(optimizer=optimizer, loss='mae')

# %%
# fit model
history = model.fit(
    normal_train_data_scaled_lstm, normal_train_data_scaled_lstm,
    epochs=200,
    batch_size=128,
    validation_split=0.3,
    callbacks=[early_stopping],
    shuffle=True,
    verbose=1)
# Out:
# Epoch 1/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 0.4629 - val_loss: 0.4506
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.4610 - val_loss: 0.4130
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.4244 - val_loss: 0.4025
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.4084 - val_loss: 0.3885
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3965 - val_loss: 0.3745
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.3800 - val_loss: 0.3700
# Epoch 7/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3743 - val_loss: 0.3677
# Epoch 8/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3743 - val_loss: 0.3599
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.3695 - val_loss: 0.3544
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3587 - val_loss: 0.3474
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.3514 - val_loss: 0.3459
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.3440 - val_loss: 0.3448
# Epoch 13/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.3486 - val_loss: 0.3403
# Epoch 14/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.3410 - val_loss: 0.3369
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3396 - val_loss: 0.3322
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3335 - val_loss: 0.3299
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.3319 - val_loss: 0.3261
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.3238 - val_loss: 0.3220
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.3239 - val_loss: 0.3157
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.3177 - val_loss: 0.3099
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.3111 - val_loss: 0.3010
# Epoch 22/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2999 - val_loss: 0.2937
# Epoch 23/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2883 - val_loss: 0.2879
# Epoch 24/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2848 - val_loss: 0.2835
# Epoch 25/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2770 - val_loss: 0.2793
# Epoch 26/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2786 - val_loss: 0.2748
# Epoch 27/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2704 - val_loss: 0.2700
# Epoch 28/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.2627 - val_loss: 0.2649
# Epoch 29/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.2571 - val_loss: 0.2594
# Epoch 30/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2531 - val_loss: 0.2540
# Epoch 31/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2480 - val_loss: 0.2476
# Epoch 32/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2408 - val_loss: 0.2417
# Epoch 33/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.2339 - val_loss: 0.2358
# Epoch 34/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.2305 - val_loss: 0.2307
# Epoch 35/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2211 - val_loss: 0.2259
# Epoch 36/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2146 - val_loss: 0.2209
# Epoch 37/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.2087 - val_loss: 0.2160
# Epoch 38/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.2041 - val_loss: 0.2106
# Epoch 39/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1998 - val_loss: 0.2054
# Epoch 40/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1941 - val_loss: 0.2011
# Epoch 41/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1890 - val_loss: 0.1964
# Epoch 42/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1858 - val_loss: 0.1921
# Epoch 43/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1789 - val_loss: 0.1889
# Epoch 44/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1768 - val_loss: 0.1855
# Epoch 45/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1734 - val_loss: 0.1834
# Epoch 46/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1702 - val_loss: 0.1816
# Epoch 47/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1705 - val_loss: 0.1800
# Epoch 48/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1677 - val_loss: 0.1782
# Epoch 49/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1659 - val_loss: 0.1771
# Epoch 50/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1645 - val_loss: 0.1760
# Epoch 51/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1623 - val_loss: 0.1753
# Epoch 52/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1620 - val_loss: 0.1743
# Epoch 53/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1595 - val_loss: 0.1737
# Epoch 54/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1578 - val_loss: 0.1731
# Epoch 55/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1568 - val_loss: 0.1723
# Epoch 56/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1573 - val_loss: 0.1716
# Epoch 57/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1549 - val_loss: 0.1709
# Epoch 58/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1548 - val_loss: 0.1701
# Epoch 59/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1565 - val_loss: 0.1693
# Epoch 60/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1500 - val_loss: 0.1687
# Epoch 61/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1477 - val_loss: 0.1677
# Epoch 62/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1522 - val_loss: 0.1669
# Epoch 63/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1496 - val_loss: 0.1658
# Epoch 64/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1490 - val_loss: 0.1650
# Epoch 65/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1480 - val_loss: 0.1640
# Epoch 66/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1475 - val_loss: 0.1634
# Epoch 67/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1464 - val_loss: 0.1627
# Epoch 68/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1437 - val_loss: 0.1619
# Epoch 69/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1428 - val_loss: 0.1612
# Epoch 70/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1442 - val_loss: 0.1603
# Epoch 71/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1414 - val_loss: 0.1595
# Epoch 72/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1406 - val_loss: 0.1585
# Epoch 73/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1419 - val_loss: 0.1580
# Epoch 74/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1382 - val_loss: 0.1571
# Epoch 75/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1379 - val_loss: 0.1563
# Epoch 76/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1370 - val_loss: 0.1554
# Epoch 77/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1369 - val_loss: 0.1544
# Epoch 78/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1350 - val_loss: 0.1534
# Epoch 79/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.1339 - val_loss: 0.1524
# Epoch 80/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.1345 - val_loss: 0.1516
# Epoch 81/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1315 - val_loss: 0.1509
# Epoch 82/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1343 - val_loss: 0.1499
# Epoch 83/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1326 - val_loss: 0.1490
# Epoch 84/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1270 - val_loss: 0.1485
# Epoch 85/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1303 - val_loss: 0.1476
# Epoch 86/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1277 - val_loss: 0.1469
# Epoch 87/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.1272 - val_loss: 0.1459
# Epoch 88/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1261 - val_loss: 0.1450
# Epoch 89/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1254 - val_loss: 0.1442
# Epoch 90/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1263 - val_loss: 0.1433
# Epoch 91/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1237 - val_loss: 0.1428
# Epoch 92/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.1212 - val_loss: 0.1418
# Epoch 93/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1220 - val_loss: 0.1405
# Epoch 94/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.1177 - val_loss: 0.1397
# Epoch 95/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1188 - val_loss: 0.1388
# Epoch 96/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.1183 - val_loss: 0.1377
# Epoch 97/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1188 - val_loss: 0.1368
# Epoch 98/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1159 - val_loss: 0.1360
# Epoch 99/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1161 - val_loss: 0.1351
# Epoch 100/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1139 - val_loss: 0.1345
# Epoch 101/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.1143 - val_loss: 0.1335
# Epoch 102/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1137 - val_loss: 0.1327
# Epoch 103/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.1115 - val_loss: 0.1320
# Epoch 104/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.1106 - val_loss: 0.1312
# Epoch 105/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.1114 - val_loss: 0.1302
# Epoch 106/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.1078 - val_loss: 0.1295
# Epoch 107/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.1078 - val_loss: 0.1282
# Epoch 108/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.1061 - val_loss: 0.1278
# Epoch 109/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.1081 - val_loss: 0.1266
# Epoch 110/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.1075 - val_loss: 0.1255
# Epoch 111/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.1039 - val_loss: 0.1246
# Epoch 112/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.1042 - val_loss: 0.1236
# Epoch 113/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.1027 - val_loss: 0.1228
# Epoch 114/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.1030 - val_loss: 0.1219
# Epoch 115/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 0.1011 - val_loss: 0.1214
# Epoch 116/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0997 - val_loss: 0.1208
# Epoch 117/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - loss: 0.0984 - val_loss: 0.1193
# Epoch 118/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 0.0993 - val_loss: 0.1184
# Epoch 119/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.0984 - val_loss: 0.1176
# Epoch 120/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0973 - val_loss: 0.1169
# Epoch 121/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0977 - val_loss: 0.1160
# Epoch 122/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0953 - val_loss: 0.1153
# Epoch 123/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0943 - val_loss: 0.1143
# Epoch 124/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0947 - val_loss: 0.1137
# Epoch 125/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0933 - val_loss: 0.1126
# Epoch 126/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0925 - val_loss: 0.1121
# Epoch 127/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0926 - val_loss: 0.1112
# Epoch 128/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0903 - val_loss: 0.1102
# Epoch 129/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0880 - val_loss: 0.1098
# Epoch 130/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0883 - val_loss: 0.1090
# Epoch 131/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0890 - val_loss: 0.1083
# Epoch 132/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0876 - val_loss: 0.1078
# Epoch 133/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0886 - val_loss: 0.1073
# Epoch 134/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0867 - val_loss: 0.1066
# Epoch 135/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0856 - val_loss: 0.1062
# Epoch 136/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0861 - val_loss: 0.1057
# Epoch 137/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0851 - val_loss: 0.1047
# Epoch 138/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0840 - val_loss: 0.1041
# Epoch 139/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0829 - val_loss: 0.1033
# Epoch 140/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0842 - val_loss: 0.1027
# Epoch 141/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0816 - val_loss: 0.1018
# Epoch 142/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0815 - val_loss: 0.1010
# Epoch 143/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0817 - val_loss: 0.1005
# Epoch 144/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0793 - val_loss: 0.0999
# Epoch 145/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0810 - val_loss: 0.0990
# Epoch 146/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0796 - val_loss: 0.0985
# Epoch 147/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0787 - val_loss: 0.0979
# Epoch 148/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0791 - val_loss: 0.0972
# Epoch 149/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0777 - val_loss: 0.0967
# Epoch 150/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0767 - val_loss: 0.0965
# Epoch 151/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0775 - val_loss: 0.0957
# Epoch 152/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0760 - val_loss: 0.0957
# Epoch 153/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0743 - val_loss: 0.0945
# Epoch 154/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0740 - val_loss: 0.0946
# Epoch 155/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0748 - val_loss: 0.0939
# Epoch 156/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0728 - val_loss: 0.0936
# Epoch 157/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0745 - val_loss: 0.0928
# Epoch 158/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0736 - val_loss: 0.0928
# Epoch 159/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0734 - val_loss: 0.0923
# Epoch 160/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0734 - val_loss: 0.0915
# Epoch 161/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0728 - val_loss: 0.0911
# Epoch 162/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0717 - val_loss: 0.0901
# Epoch 163/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0712 - val_loss: 0.0894
# Epoch 164/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0709 - val_loss: 0.0894
# Epoch 165/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0707 - val_loss: 0.0886
# Epoch 166/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0694 - val_loss: 0.0879
# Epoch 167/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0685 - val_loss: 0.0879
# Epoch 168/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0683 - val_loss: 0.0868
# Epoch 169/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0668 - val_loss: 0.0863
# Epoch 170/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0678 - val_loss: 0.0858
# Epoch 171/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0673 - val_loss: 0.0852
# Epoch 172/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0643 - val_loss: 0.0854
# Epoch 173/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0663 - val_loss: 0.0843
# Epoch 174/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.0654 - val_loss: 0.0843
# Epoch 175/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0657 - val_loss: 0.0830
# Epoch 176/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0644 - val_loss: 0.0840
# Epoch 177/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0641 - val_loss: 0.0824
# Epoch 178/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0623 - val_loss: 0.0819
# Epoch 179/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0639 - val_loss: 0.0821
# Epoch 180/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0630 - val_loss: 0.0811
# Epoch 181/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0612 - val_loss: 0.0805
# Epoch 182/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0614 - val_loss: 0.0808
# Epoch 183/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0617 - val_loss: 0.0803
# Epoch 184/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0613 - val_loss: 0.0798
# Epoch 185/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0610 - val_loss: 0.0792
# Epoch 186/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0606 - val_loss: 0.0788
# Epoch 187/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0598 - val_loss: 0.0784
# Epoch 188/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0586 - val_loss: 0.0778
# Epoch 189/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0593 - val_loss: 0.0781
# Epoch 190/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0589 - val_loss: 0.0775
# Epoch 191/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0587 - val_loss: 0.0769
# Epoch 192/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0581 - val_loss: 0.0765
# Epoch 193/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0565 - val_loss: 0.0764
# Epoch 194/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0574 - val_loss: 0.0757
# Epoch 195/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0568 - val_loss: 0.0757
# Epoch 196/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0558 - val_loss: 0.0748
# Epoch 197/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0563 - val_loss: 0.0751
# Epoch 198/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0557 - val_loss: 0.0739
# Epoch 199/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0557 - val_loss: 0.0738
# Epoch 200/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0550 - val_loss: 0.0735
# Restoring model weights from the end of the best epoch: 200.

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], 'b-', label='Training loss', linewidth=2)
plt.plot(history.history['val_loss'], 'r--', label='Validation loss', linewidth=2)

# Customize the plot
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss (MAE)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)

# Add legend with larger font
plt.legend(fontsize=12)

# Adjust y-axis to start from 0
plt.ylim(bottom=0)

# Add minor grid lines for finer scale
plt.minorticks_on()
plt.grid(True, which='minor', linestyle=':', alpha=0.4)

# Make axis labels more readable
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Adjust layout to prevent label cutoff
plt.tight_layout()

plt.show()

# %%
from keras import ops
model.save('../../../models/lstm_autoencoder_best.keras')

# %%
load_model = tf.keras.models.load_model('../../../models/lstm_autoencoder_best.keras')

# %%
# Calculate reconstruction errors for test data
train_reconstructions_normal = load_model.predict(normal_train_data_scaled_lstm)
train_loss_normal = tf.keras.losses.mae(train_reconstructions_normal, normal_train_data_scaled_lstm)
# Flatten the loss array and convert to numpy for plotting
train_loss_normal_flat = train_loss_normal.numpy().flatten()

plt.hist(train_loss_normal_flat, bins=50)
plt.xlabel("Reconstruction Error (Normal Training Data)")
plt.ylabel("Number of Examples")
plt.title("Distribution of Reconstruction Errors")
plt.show()
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
# Calculate reconstruction errors for abnormal data
train_reconstructions_abnormal = load_model.predict(abnormal_train_data_scaled_lstm)
train_loss_abnormal = tf.keras.losses.mae(train_reconstructions_abnormal, abnormal_train_data_scaled_lstm)
# Flatten the loss array and convert to numpy for plotting
train_loss_abnormal_flat = train_loss_abnormal.numpy().flatten()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(train_loss_abnormal_flat, bins=50, color='orange', alpha=0.7)
plt.xlabel("Reconstruction Error (Abnormal Training Data)")
plt.ylabel("Number of Examples")
plt.title("Distribution of Reconstruction Errors - Abnormal Data")
plt.show()

# Calculate and display minimum reconstruction error for abnormal data
min_error = np.min(train_loss_abnormal_flat)
print(f"\nMinimum reconstruction error for abnormal data: {min_error:.4f}")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Minimum reconstruction error for abnormal data: 0.2007

# %%
# Create combined histogram plot
plt.figure(figsize=(10, 6))
plt.hist(train_loss_normal_flat, bins=50, alpha=0.7, label='Normal', color='blue')
plt.hist(train_loss_abnormal_flat, bins=50, alpha=0.7, label='Abnormal', color='red')
plt.ylim(0, 60)
plt.xlabel('Reconstruction Error (MAE)')
plt.ylabel('Number of Examples')
plt.title('Distribution of Reconstruction Errors - LSTM Autoencoder')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Calculate thresholds
low_threshold = 0.197 # all anomalies are caught
high_threshold = np.percentile(train_loss_normal, 99.99)  # Loose threshold (99th percentile)
print("Low threshold: ", low_threshold)
print("High threshold: ", high_threshold)
# Out:
# Low threshold:  0.197
# High threshold:  0.6914749

# %%
best_threshold, best_f1 = plt_optimal_threshold(train_loss_normal, train_loss_abnormal)
# Out:
# Optimal threshold (best F1 score): 0.3767
# Best F1 score: 0.9619

# %%
import json
# Save threshold to a JSON file
threshold_data = {
    'low_threshold': float(low_threshold),  # Convert to native Python float
    'middle_threshold': float(best_threshold),  # Convert numpy.float32 to native Python float
    'high_threshold': float(high_threshold),  # Convert numpy.float32 to native Python float
}

# Save in the same directory as the model
with open('../../../models/lstm_thresholds.json', 'w') as f:
    json.dump(threshold_data, f)

# %%
# Verify the saved data
with open('../../../models/lstm_thresholds.json', 'r') as f:
    loaded_thresholds = json.load(f)
print("Saved thresholds:", loaded_thresholds)
# Out:
# Saved thresholds: {'low_threshold': 0.197, 'middle_threshold': 0.37674182653427124, 'high_threshold': 0.6914749145507812}
